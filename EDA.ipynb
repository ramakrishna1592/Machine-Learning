# %% [markdown]
# ### Area And Population By States-Census -2011 India

# %%
import sys
print(sys.version)
# Out:
# 3.5.3 | packaged by conda-forge | (default, Feb  9 2017, 14:37:12)
# [GCC 4.8.2 20140120 (Red Hat 4.8.2-15)]

# %%
#import important libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#load the data
xl = pd.ExcelFile("data/PopulationbyStates-Census.xls")
xl.sheet_names
# Out:
# ['Table 2.1']

# %%
explore = pd.read_excel('data/PopulationbyStates-Census.xls')
explore.head(10)
# Out:
#                                  POPULATION Unnamed: 1         Unnamed: 2  \
# 0  TABLE 2.1- AREA AND POPULATION BY STATES        NaN                NaN
# 1                             (Census-2011)        NaN                NaN
# 2                                       NaN        NaN         Population
# 3                             India/ State/    Area in                NaN
# 4                          Union Territory    sq. kms.              Males
# 5                                         1          2                  3
# 6                      INDIA (1) ++            3287469          623270258
# 7                            Andhra Pradesh     275045           42442146
# 8                         Arunachal Pradesh      83743             713912
# 9                                     Assam      78438           15939443
#
#       Unnamed: 3    Unnamed: 4         Unnamed: 5     Unnamed: 6 Unnamed: 7
# 0            NaN           NaN                NaN            NaN        NaN
# ...

# %%
explore.tail(11)
# Out:
#                                            POPULATION Unnamed: 1 Unnamed: 2  \
# 43                                        Puducherry         490     612511
# 44     Source: Office of Registrar General of Indi...        NaN        NaN
# 45   *  The area figures of States and U.T's do no...        NaN        NaN
# 46  (i)  The shortfall of 7 square km. area of Mad...        NaN        NaN
# 47  ( ii )  Disputed area of 13 square km. between...        NaN        NaN
# 48  (1) The population figures excludes population...        NaN        NaN
# 49   ++  Area figures includes the area under unla...        NaN        NaN
# 50          5,180 sq. km.illegally  handed over by...        NaN        NaN
# 51                                                NaN        NaN        NaN
# 52                                                NaN        NaN        NaN
# 53                                                           NaN        NaN
#
# ...

# %%
explore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 8 columns):
# POPULATION    50 non-null object
# Unnamed: 1    39 non-null object
# Unnamed: 2    39 non-null object
# Unnamed: 3    38 non-null object
# Unnamed: 4    38 non-null object
# Unnamed: 5    38 non-null object
# Unnamed: 6    38 non-null object
# Unnamed: 7    1 non-null object
# dtypes: object(8)
# memory usage: 3.5+ KB

# %%
# delete the first 5 rows and last 10 rows
data = explore.drop(explore.index[0:4])
data.tail(11)
# Out:
#                                            POPULATION Unnamed: 1 Unnamed: 2  \
# 43                                        Puducherry         490     612511
# 44     Source: Office of Registrar General of Indi...        NaN        NaN
# 45   *  The area figures of States and U.T's do no...        NaN        NaN
# 46  (i)  The shortfall of 7 square km. area of Mad...        NaN        NaN
# 47  ( ii )  Disputed area of 13 square km. between...        NaN        NaN
# 48  (1) The population figures excludes population...        NaN        NaN
# 49   ++  Area figures includes the area under unla...        NaN        NaN
# 50          5,180 sq. km.illegally  handed over by...        NaN        NaN
# 51                                                NaN        NaN        NaN
# 52                                                NaN        NaN        NaN
# 53                                                           NaN        NaN
#
# ...

# %%
data = data.drop(data.index[-10:-1])
data
# Out:
#                  POPULATION Unnamed: 1         Unnamed: 2     Unnamed: 3  \
# 4          Union Territory    sq. kms.              Males        Females
# 5                         1          2                  3              4
# 6      INDIA (1) ++            3287469          623270258      587584719
# 7            Andhra Pradesh     275045           42442146       42138631
# 8         Arunachal Pradesh      83743             713912         669815
# 9                     Assam      78438           15939443       15266133
# 10                    Bihar      94163           54278157       49821295
# 11             Chhattisgarh     135192           12832895       12712303
# 12                     Goa        3702             739140         719405
# 13                  Gujarat     196244           31491260       28948432
# 14                  Haryana      44212           13494734       11856728
# 15         Himachal Pradesh      55673            3481873        3382729
# ...

# %%
data.columns
# Out:
# Index(['POPULATION', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
# 4th row contains labels of interest
data.loc[4].values
# Out:
# array([' Union Territory ', ' sq. kms.', ' Males', 'Females', 'Persons',
#        ' Rural', 'Urban', nan], dtype=object)

# %%
# change the 4th row first column value to 'State'
data.loc[4][0] = 'State'
data.loc[4][1] = 'Area'
data.loc[4][7] = 'Dummy'
data.loc[4].values
# Out:
# array(['State', 'Area', ' Males', 'Females', 'Persons', ' Rural', 'Urban',
#        'Dummy'], dtype=object)

# %%
#store total of india
ind_total = data.loc[6].values
ind_total[0] = 'Total'
ind_total
# Out:
# array(['Total', 3287469, 623270258, 587584719, 1210854977, 833748852,
#        377106125, nan], dtype=object)

# %%
# resetting index
data = data.reset_index(drop=True)
data
# Out:
#                  POPULATION Unnamed: 1         Unnamed: 2     Unnamed: 3  \
# 0                     State       Area              Males        Females
# 1                         1          2                  3              4
# 2                     Total    3287469          623270258      587584719
# 3            Andhra Pradesh     275045           42442146       42138631
# 4         Arunachal Pradesh      83743             713912         669815
# 5                     Assam      78438           15939443       15266133
# 6                     Bihar      94163           54278157       49821295
# 7              Chhattisgarh     135192           12832895       12712303
# 8                      Goa        3702             739140         719405
# 9                   Gujarat     196244           31491260       28948432
# 10                  Haryana      44212           13494734       11856728
# 11         Himachal Pradesh      55673            3481873        3382729
# ...

# %%
#required data lies between row's index's 3 and 40
#required column names lie in row index 0
# required Total value lie in row index  2


#Operations to do

# 1)Change data column names to labels in row 1
data.columns = data.iloc[0].values
data
# Out:
#                       State     Area              Males        Females  \
# 4                     State     Area              Males        Females
# 5                         1        2                  3              4
# 6                     Total  3287469          623270258      587584719
# 7            Andhra Pradesh   275045           42442146       42138631
# 8         Arunachal Pradesh    83743             713912         669815
# 9                     Assam    78438           15939443       15266133
# 10                    Bihar    94163           54278157       49821295
# 11             Chhattisgarh   135192           12832895       12712303
# 12                     Goa      3702             739140         719405
# 13                  Gujarat   196244           31491260       28948432
# 14                  Haryana    44212           13494734       11856728
# 15         Himachal Pradesh    55673            3481873        3382729
# ...

# %%
# drop row indexes 29 and 30
data = data.drop(data.index[29:31]).reset_index(drop=True)
data
# Out:
#                       State     Area      Males    Females     Persons  \
# 0                     Total  3287469  623270258  587584719  1210854977
# 1            Andhra Pradesh   275045   42442146   42138631    84580777
# 2         Arunachal Pradesh    83743     713912     669815     1383727
# 3                     Assam    78438   15939443   15266133    31205576
# 4                     Bihar    94163   54278157   49821295   104099452
# 5              Chhattisgarh   135192   12832895   12712303    25545198
# 6                      Goa      3702     739140     719405     1458545
# 7                   Gujarat   196244   31491260   28948432    60439692
# 8                   Haryana    44212   13494734   11856728    25351462
# 9          Himachal Pradesh    55673    3481873    3382729     6864602
# 10   Jammu & Kashmir (1) ++   222236    6640662    5900640    12541302
# 11                Jharkhand    79716   16930315   16057819    32988134
# ...

# %%
data.reset_index(drop=True)
s = data

# %%
s
# Out:
#                       State     Area              Males        Females  \
# 4            Andhra Pradesh   275045           42442146       42138631
# 5         Arunachal Pradesh    83743             713912         669815
# 6                     Assam    78438           15939443       15266133
# 7                     Bihar    94163           54278157       49821295
# 8              Chhattisgarh   135192           12832895       12712303
# 9                      Goa      3702             739140         719405
# 10                  Gujarat   196244           31491260       28948432
# 11                  Haryana    44212           13494734       11856728
# 12         Himachal Pradesh    55673            3481873        3382729
# 13   Jammu & Kashmir (1) ++   222236            6640662        5900640
# 14                Jharkhand    79716           16930315       16057819
# 15                Karnataka   191791           30966657       30128640
# ...

# %%
# shifting a row to the end, in this case the first row
target_row = data.iloc[[0],:]
data = data.shift(-1)
data.iloc[-1] = target_row.squeeze()
data
# Out:
#                       State     Area              Males        Females  \
# 4            Andhra Pradesh   275045           42442146       42138631
# 5         Arunachal Pradesh    83743             713912         669815
# 6                     Assam    78438           15939443       15266133
# 7                     Bihar    94163           54278157       49821295
# 8              Chhattisgarh   135192           12832895       12712303
# 9                      Goa      3702             739140         719405
# 10                  Gujarat   196244           31491260       28948432
# 11                  Haryana    44212           13494734       11856728
# 12         Himachal Pradesh    55673            3481873        3382729
# 13   Jammu & Kashmir (1) ++   222236            6640662        5900640
# 14                Jharkhand    79716           16930315       16057819
# 15                Karnataka   191791           30966657       30128640
# ...

# %%
s = s.reset_index(drop=True)

# %%
s.head()
# Out:
#                 State    Area     Males   Females    Persons     Rural  \
# 0      Andhra Pradesh  275045  42442146  42138631   84580777  56361702
# 1   Arunachal Pradesh   83743    713912    669815    1383727   1066358
# 2               Assam   78438  15939443  15266133   31205576  26807034
# 3               Bihar   94163  54278157  49821295  104099452  92341436
# 4        Chhattisgarh  135192  12832895  12712303   25545198  19607961
#
#       Urban Dummy
# 0  28219075   NaN
# 1    317369   NaN
# 2   4398542   NaN
# 3  11758016   NaN
# 4   5937237   NaN

# %%
s.tail()
# Out:
#            State     Area              Males        Females       Persons  \
# 36   Puducherry       490             612511         635442       1247953
# 37                    NaN                NaN            NaN           NaN
# 38         State     Area              Males        Females       Persons
# 39             1        2                  3              4             5
# 40         Total  3287469          623270258      587584719    1210854977
#
#                 Rural          Urban  Dummy
# 36             395200         852753    NaN
# 37                NaN            NaN    NaN
# 38              Rural          Urban  Dummy
# 39                  6              7    NaN
# 40          833748852      377106125    NaN

# %%
s = s.drop(s.index[37:40]).reset_index(drop=True)

# %%
s = s.drop(s.index[28:30]).reset_index(drop=True)
s
# Out:
#                       State     Area      Males    Females     Persons  \
# 0            Andhra Pradesh   275045   42442146   42138631    84580777
# 1         Arunachal Pradesh    83743     713912     669815     1383727
# 2                     Assam    78438   15939443   15266133    31205576
# 3                     Bihar    94163   54278157   49821295   104099452
# 4              Chhattisgarh   135192   12832895   12712303    25545198
# 5                      Goa      3702     739140     719405     1458545
# 6                   Gujarat   196244   31491260   28948432    60439692
# 7                   Haryana    44212   13494734   11856728    25351462
# 8          Himachal Pradesh    55673    3481873    3382729     6864602
# 9    Jammu & Kashmir (1) ++   222236    6640662    5900640    12541302
# 10                Jharkhand    79716   16930315   16057819    32988134
# 11                Karnataka   191791   30966657   30128640    61095297
# ...

# %%
k = s
k = k.drop(labels='Dummy', axis=1)
k
# Out:
#                       State     Area      Males    Females     Persons  \
# 0            Andhra Pradesh   275045   42442146   42138631    84580777
# 1         Arunachal Pradesh    83743     713912     669815     1383727
# 2                     Assam    78438   15939443   15266133    31205576
# 3                     Bihar    94163   54278157   49821295   104099452
# 4              Chhattisgarh   135192   12832895   12712303    25545198
# 5                      Goa      3702     739140     719405     1458545
# 6                   Gujarat   196244   31491260   28948432    60439692
# 7                   Haryana    44212   13494734   11856728    25351462
# 8          Himachal Pradesh    55673    3481873    3382729     6864602
# 9    Jammu & Kashmir (1) ++   222236    6640662    5900640    12541302
# 10                Jharkhand    79716   16930315   16057819    32988134
# 11                Karnataka   191791   30966657   30128640    61095297
# ...

# %%
data = k
data.head()
# Out:
#                 State    Area     Males   Females    Persons     Rural  \
# 0      Andhra Pradesh  275045  42442146  42138631   84580777  56361702
# 1   Arunachal Pradesh   83743    713912    669815    1383727   1066358
# 2               Assam   78438  15939443  15266133   31205576  26807034
# 3               Bihar   94163  54278157  49821295  104099452  92341436
# 4        Chhattisgarh  135192  12832895  12712303   25545198  19607961
#
#       Urban
# 0  28219075
# 1    317369
# 2   4398542
# 3  11758016
# 4   5937237

# %%
states = data.iloc[0:28]
states
# Out:
#                       State    Area      Males   Females    Persons  \
# 0            Andhra Pradesh  275045   42442146  42138631   84580777
# 1         Arunachal Pradesh   83743     713912    669815    1383727
# 2                     Assam   78438   15939443  15266133   31205576
# 3                     Bihar   94163   54278157  49821295  104099452
# 4              Chhattisgarh  135192   12832895  12712303   25545198
# 5                      Goa     3702     739140    719405    1458545
# 6                   Gujarat  196244   31491260  28948432   60439692
# 7                   Haryana   44212   13494734  11856728   25351462
# 8          Himachal Pradesh   55673    3481873   3382729    6864602
# 9    Jammu & Kashmir (1) ++  222236    6640662   5900640   12541302
# 10                Jharkhand   79716   16930315  16057819   32988134
# 11                Karnataka  191791   30966657  30128640   61095297
# 12                   Kerala   38852   16027412  17378649   33406061
# ...

# %%
ut = data.iloc[28:35]
ut = ut.rename(columns={'State': 'Union Territory'})
ut
# Out:
#     Union Territory  Area    Males  Females   Persons   Rural     Urban
# 28   A.& N.Islands   8249   202871   177710    380581  237093    143488
# 29      Chandigarh    114   580663   474787   1055450   28991   1026459
# 30    D.& N.Haveli    491   193760   149949    343709  183114    160595
# 31     Daman & Diu    111   150301    92946    243247   60396    182851
# 32           Delhi   1483  8987326  7800615  16787941  419042  16368899
# 33     Lakshadweep     30    33123    31350     64473   14141     50332
# 34      Puducherry    490   612511   635442   1247953  395200    852753

# %%
# Lets look at state data
  # number of states
n = states['State'].count()
print('Total number of states: {0}'.format(n))
  # total area
area = states['Area'].sum()
print('Total area of the states in sq Km: {0}'.format(area))
# Out:
# Total number of states: 28
# Total area of the states in sq Km: 3276501

# %%
states.head()
# Out:
#                 State    Area     Males   Females    Persons     Rural  \
# 0      Andhra Pradesh  275045  42442146  42138631   84580777  56361702
# 1   Arunachal Pradesh   83743    713912    669815    1383727   1066358
# 2               Assam   78438  15939443  15266133   31205576  26807034
# 3               Bihar   94163  54278157  49821295  104099452  92341436
# 4        Chhattisgarh  135192  12832895  12712303   25545198  19607961
#
#       Urban
# 0  28219075
# 1    317369
# 2   4398542
# 3  11758016
# 4   5937237

# %%
states.set_index('State')
states
# Out:
#                            Area      Males   Females    Persons      Rural  \
# State
#  Andhra Pradesh          275045   42442146  42138631   84580777   56361702
#  Arunachal Pradesh        83743     713912    669815    1383727    1066358
#  Assam                    78438   15939443  15266133   31205576   26807034
#  Bihar                    94163   54278157  49821295  104099452   92341436
#  Chhattisgarh            135192   12832895  12712303   25545198   19607961
#  Goa                       3702     739140    719405    1458545     551731
#  Gujarat                 196244   31491260  28948432   60439692   34694609
#  Haryana                  44212   13494734  11856728   25351462   16509359
#  Himachal Pradesh         55673    3481873   3382729    6864602    6176050
#  Jammu & Kashmir (1) ++  222236    6640662   5900640   12541302    9108060
#  Jharkhand                79716   16930315  16057819   32988134   25055073
# ...

# %%
#sort by area
states.sort_values(by='Area',ascending=False)
# Out:
#                            Area      Males   Females    Persons      Rural  \
# State
#  Rajasthan               342239   35550997  32997440   68548437   51500352
#  Madhya Pradesh          308252   37612306  35014503   72626809   52557404
#  Maharashtra             307713   58243056  54131277  112374333   61556074
#  Andhra Pradesh          275045   42442146  42138631   84580777   56361702
#  Uttar Pradesh           240928  104480510  95331831  199812341  155317278
#  Jammu & Kashmir (1) ++  222236    6640662   5900640   12541302    9108060
#  Gujarat                 196244   31491260  28948432   60439692   34694609
#  Karnataka               191791   30966657  30128640   61095297   37469335
#  Odisha                  155707   21212136  20762082   41974218   34970562
#  Chhattisgarh            135192   12832895  12712303   25545198   19607961
#  Tamil Nadu              130060   36137975  36009055   72147030   37229590
# ...

# %%
states.columns = states.columns.str.replace('\s+','')

# %%
#Population density (No of ppl / sq km)
states['Density'] = states['Persons']/states['Area']
#Male Females ration
states['MF_ratio'] = states['Males']/states['Females']
#Urban Rural ratio
states['UR_ratio'] = states['Urban']/states['Rural']
states
# Out:
#                            Area      Males   Females    Persons      Rural  \
# State
#  Andhra Pradesh          275045   42442146  42138631   84580777   56361702
#  Arunachal Pradesh        83743     713912    669815    1383727    1066358
#  Assam                    78438   15939443  15266133   31205576   26807034
#  Bihar                    94163   54278157  49821295  104099452   92341436
#  Chhattisgarh            135192   12832895  12712303   25545198   19607961
#  Goa                       3702     739140    719405    1458545     551731
#  Gujarat                 196244   31491260  28948432   60439692   34694609
#  Haryana                  44212   13494734  11856728   25351462   16509359
#  Himachal Pradesh         55673    3481873   3382729    6864602    6176050
#  Jammu & Kashmir (1) ++  222236    6640662   5900640   12541302    9108060
#  Jharkhand                79716   16930315  16057819   32988134   25055073
# ...
